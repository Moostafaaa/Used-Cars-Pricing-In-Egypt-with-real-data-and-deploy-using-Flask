# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_selection import RFE, SelectFromModel
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,SCORERS
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
sns.set(rc={'figure.figsize': [8, 8]}, font_scale=1)

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0        Make       Model  year    CC  distance transmission  \
# 0           0   Chevrolet        Aveo  2012  1500     99000       manual
# 1           1  Volkswagen       Jetta  2008  1500    200000    automatic
# 2           2        Opel       Astra  2020  1500     57000    automatic
# 3           3       Skoda  Octavia A5  2007  1600    150000    automatic
# 4           4     Hyundai   Accent RB  2015  1600    135000    automatic
#
#     color   price
# 0  Silver  127000
# 1  Silver  179000
# 2  Silver  325000
# 3    Gray  163000
# 4   Black  190000

# %%
df.drop('Unnamed: 0' , axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6471 entries, 0 to 6470
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6471 non-null   int64
#  1   Make          6471 non-null   object
#  2   Model         6471 non-null   object
#  3   year          6471 non-null   int64
#  4   CC            6471 non-null   int64
#  5   distance      6471 non-null   int64
#  6   transmission  6471 non-null   object
#  7   color         6471 non-null   object
#  8   price         6471 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 455.1+ KB

# %%
df.describe()
# Out:
#               year           CC       distance          price
# count  6471.000000  6471.000000    6471.000000    6471.000000
# mean   2010.276155  1569.445063  150509.845155  141289.367795
# std       6.241551    55.100305   66950.257548   66280.740127
# min    1990.000000  1360.000000      45.000000   35000.000000
# 25%    2007.000000  1500.000000  100000.000000   90000.000000
# 50%    2011.000000  1600.000000  150000.000000  128000.000000
# 75%    2015.000000  1600.000000  200000.000000  180000.000000
# max    2020.000000  1700.000000  375000.000000  350000.000000

# %% [markdown]
# # EDA and Visualization

# %% [markdown]
# ## Different car manufacturers price analysis

# %%
df.groupby('Make').describe()['price'].sort_values('max')
# Out:
#              count           mean            std       min       25%  \
# Make
# Daihatsu       1.0   42000.000000            NaN   42000.0   42000.0
# Chana          1.0   47000.000000            NaN   47000.0   47000.0
# Lifan          1.0   50000.000000            NaN   50000.0   50000.0
# Faw            2.0   54000.000000   19798.989873   40000.0   47000.0
# Jac            2.0   86500.000000   19091.883092   73000.0   79750.0
# Great Wall     3.0   90000.000000   10000.000000   80000.0   85000.0
# Saipa          9.0   75777.777778   14498.084165   57000.0   70000.0
# Audi           2.0   75000.000000   49497.474683   40000.0   57500.0
# Soueast        3.0  111666.666667    2886.751346  110000.0  110000.0
# DFM            1.0  117000.000000            NaN  117000.0  117000.0
# Chrysler       2.0   85000.000000   56568.542495   45000.0   65000.0
# Brilliance    26.0  100961.538462   17918.662381   68000.0   90000.0
# Daewoo       494.0   79524.291498   12229.732043   40000.0   72000.0
# Speranza     208.0   76649.038462   14144.762232   40000.0   69750.0
# Lada         125.0   85352.000000   37829.681127   35000.0   47000.0
# Senova        11.0  121818.181818   24003.408849   70000.0  115000.0
# Zotye          2.0  157500.000000   17677.669530  145000.0  151250.0
# Changan        2.0  155000.000000   21213.203436  140000.0  147500.0
# Geely        201.0  100268.656716   25541.289370   35000.0   85000.0
# Suzuki         5.0  166000.000000    8215.838363  160000.0  160000.0
# Emgrand        2.0  140500.000000   77074.639149   86000.0  113250.0
# Subaru        12.0  152750.000000   32552.405301  105000.0  132250.0
# Chery         78.0  122378.205128   46203.684138   39000.0   98875.0
# Proton        77.0  107311.688312   34195.359696   45000.0   85000.0
# Honda         43.0  137837.209302   55046.703215   60000.0   81500.0
# Citroën       30.0  143433.333333   64635.681047   58000.0   86250.0
# Pontiac        1.0  280000.000000            NaN  280000.0  280000.0
# Haima          7.0  150857.142857   77234.337293   61000.0  110000.0
# Ford          42.0  143476.190476   72818.932842   35000.0   75000.0
# Ds             2.0  285000.000000   21213.203436  270000.0  277500.0
# Byd          206.0  130291.262136   30897.827240   57000.0  110000.0
# Mazda         47.0  172468.085106   81729.897426   45000.0  117500.0
# Nissan       471.0  163826.963907   42629.256450   60000.0  135000.0
# Mitsubishi   362.0  179382.596685   58243.810327   35000.0  135000.0
# Fiat         192.0   94304.687500   83904.159542   35000.0   47000.0
# Chevrolet    857.0  128658.693116   37164.211847   57000.0  100000.0
# MG            36.0  245430.555556   69019.785236   90000.0  188750.0
# Peugeot      112.0  148705.348214   78569.021369   35000.0   70000.0
# Seat          53.0  170188.679245  104178.296980   35000.0   75000.0
# Volkswagen    83.0  199951.807229   55337.303524   85000.0  175000.0
# Opel         225.0  174137.777778   79784.887378   50000.0  100000.0
# Renault      460.0  129692.391304   55083.581241   35000.0   95000.0
# BMW           51.0  213843.137255   72059.523326   80000.0  152500.0
# Mercedes      22.0  286727.272727   56047.753294  138000.0  261250.0
# Volvo         12.0  277916.666667   47071.431856  200000.0  247500.0
# Toyota       194.0  211278.350515   77035.721782   52000.0  161250.0
# Hyundai     1024.0  145220.214844   64267.749974   35000.0  100000.0
# Skoda        232.0  164579.741379   55030.934818   65000.0  125000.0
# Kia          437.0  180322.654462   71358.596714   40000.0  135000.0
#
#                  50%       75%       max
# Make
# Daihatsu     42000.0   42000.0   42000.0
# Chana        47000.0   47000.0   47000.0
# Lifan        50000.0   50000.0   50000.0
# Faw          54000.0   61000.0   68000.0
# Jac          86500.0   93250.0  100000.0
# Great Wall   90000.0   95000.0  100000.0
# Saipa        73000.0   85000.0  105000.0
# Audi         75000.0   92500.0  110000.0
# Soueast     110000.0  112500.0  115000.0
# DFM         117000.0  117000.0  117000.0
# Chrysler     85000.0  105000.0  125000.0
# Brilliance   98500.0  118750.0  128000.0
# Daewoo       80000.0   85000.0  130000.0
# Speranza     75000.0   82000.0  135000.0
# Lada         90000.0  115000.0  164000.0
# Senova      122000.0  129000.0  170000.0
# Zotye       157500.0  163750.0  170000.0
# Changan     155000.0  162500.0  170000.0
# Geely       100000.0  115000.0  180000.0
# Suzuki      165000.0  165000.0  180000.0
# Emgrand     140500.0  167750.0  195000.0
# Subaru      147500.0  168750.0  210000.0
# Chery       117500.0  155000.0  220000.0
# Proton      100000.0  120000.0  230000.0
# Honda       145000.0  176000.0  260000.0
# Citroën     137500.0  170000.0  275000.0
# Pontiac     280000.0  280000.0  280000.0
# Haima       130000.0  180000.0  285000.0
# Ford        149000.0  188750.0  288000.0
# Ds          285000.0  292500.0  300000.0
# Byd         130000.0  149250.0  300000.0
# Mazda       155000.0  254500.0  320000.0
# Nissan      155000.0  187500.0  325000.0
# Mitsubishi  178000.0  227500.0  330000.0
# Fiat         55000.0   80000.0  330000.0
# Chevrolet   120000.0  150000.0  330000.0
# MG          259000.0  292500.0  340000.0
# Peugeot     146500.0  186250.0  340000.0
# Seat        138000.0  280000.0  340000.0
# Volkswagen  195000.0  225000.0  345000.0
# Opel        170000.0  235000.0  345000.0
# Renault     120000.0  150000.0  350000.0
# BMW         210000.0  273500.0  350000.0
# Mercedes    310000.0  325000.0  350000.0
# Volvo       290000.0  310000.0  350000.0
# Toyota      212000.0  269250.0  350000.0
# Hyundai     130000.0  183500.0  350000.0
# Skoda       150000.0  200000.0  350000.0
# Kia         185000.0  230000.0  350000.0

# %%
sns.distplot(df['price'],color='m')
# Out:
# C:\Users\Mostafa Hesham\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['price'], kde=False, color='m' ,bins=100)
# Out:
# C:\Users\Mostafa Hesham\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### note that most cars prices are less than 200,000 EGP

# %%
sns.kdeplot(df['price'], shade=True, color='m')

# %% [markdown]
# ### what the top 10 most expensive cars?

# %%
df.sort_values('price',ascending=False).head(10)
# Out:
#       Unnamed: 0      Make       Model  year    CC  distance transmission  \
# 4926        4926       Kia      Cerato  2018  1600     79000    automatic
# 3734        3734    Toyota     Corolla  2020  1600     45000    automatic
# 3229        3229    Toyota     Corolla  2017  1600    136000    automatic
# 1125        1125    Toyota     Corolla  2018  1600    100000    automatic
# 5435        5435  Mercedes       C 180  2011  1600    153000    automatic
# 6222        6222   Hyundai  Elantra AD  2019  1600     40000    automatic
# 1780        1780       BMW         316  2014  1600    175000    automatic
# 3180        3180    Toyota     Corolla  2019  1600     73000    automatic
# 405          405     Volvo         S60  2015  1600    131000    automatic
# 3398        3398     Skoda  Octavia A7  2016  1600    119000    automatic
#
#            color   price
# 4926      Silver  350000
# 3734      Silver  350000
# 3229      Silver  350000
# 1125        Gray  350000
# 5435       White  350000
# 6222  Light grey  350000
# 1780       Black  350000
# 3180   Dark blue  350000
# 405       Silver  350000
# 3398  Light grey  350000

# %%
df.sort_values('price',ascending=True).head(10)
# Out:
#       Unnamed: 0        Make   Model  year    CC  distance transmission  \
# 5598        5598        Fiat  Shahin  2001  1400    150000       manual
# 3132        3132  Mitsubishi  Lancer  1990  1600    300000       manual
# 4514        4514        Fiat  Shahin  2006  1600    150000       manual
# 5868        5868     Peugeot     405  1994  1600    140000       manual
# 2632        2632        Fiat   Dogan  1995  1600    220000       manual
# 2285        2285        Fiat  Shahin  1995  1600    200000       manual
# 2351        2351        Ford  Escort  1998  1600    200000       manual
# 6134        6134        Lada    2105  1995  1600     75000       manual
# 4362        4362     Hyundai   Excel  1995  1600    200000       manual
# 5295        5295     Hyundai   Excel  1996  1600    150000       manual
#
#           color  price
# 5598  Dark blue  35000
# 3132  Dark blue  35000
# 4514      White  35000
# 5868      White  35000
# 2632     Silver  35000
# 2285      Green  35000
# 2351       Blue  35000
# 6134   Dark red  35000
# 4362      White  35000
# 5295       Blue  35000

# %% [markdown]
# ### what is the mean price for each maker and each model ?

# %%
df.groupby('Model').describe()['price']
# Out:
#        count           mean           std       min       25%       50%  \
# Model
# 19       2.0   38500.000000    707.106781   38000.0   38250.0   38500.0
# 200      1.0  285000.000000           NaN  285000.0  285000.0  285000.0
# 2017     1.0   47000.000000           NaN   47000.0   47000.0   47000.0
# 207      7.0  126285.714286  28376.717485   85000.0  116000.0  127000.0
# 2105     2.0   37500.000000   3535.533906   35000.0   36250.0   37500.0
# ...      ...            ...           ...       ...       ...       ...
# XD       1.0  120000.000000           NaN  120000.0  120000.0  120000.0
# Xsara    7.0   65000.000000   8062.257748   58000.0   60000.0   64000.0
# Yaris   16.0  194375.000000  48917.447467  130000.0  140000.0  200000.0
# Z300     2.0  157500.000000  17677.669530  145000.0  151250.0  157500.0
# ZS      13.0  248346.153846  62624.337859   90000.0  245000.0  260000.0
#
#             75%       max
# Model
# 19      38750.0   39000.0
# 200    285000.0  285000.0
# 2017    47000.0   47000.0
# 207    130000.0  180000.0
# 2105    38750.0   40000.0
# ...         ...       ...
# XD     120000.0  120000.0
# Xsara   65500.0   82000.0
# Yaris  241250.0  260000.0
# Z300   163750.0  170000.0
# ZS     283500.0  320000.0
#
# [188 rows x 8 columns]

# %%
sns.jointplot(x='price', y='Make', data=df,height=9, kind='scatter')

# %% [markdown]
# ## what are the most 5 frequent colors of cars ?

# %%
df['color'].value_counts().nlargest(5)
# Out:
# Silver        1335
# Black         1205
# White          533
# Light grey     514
# Dark red       501
# Name: color, dtype: int64

# %% [markdown]
# ##  what are the most frequent colors for most expensive cars?

# %%
df.sort_values('price',ascending=False).head(100)['color'].value_counts()
# Out:
# Silver        28
# Black         21
# White         15
# Gray           9
# Light grey     5
# Red            5
# Dark blue      3
# Gold           3
# Dark red       3
# Brown          2
# Petroleum      2
# Blue           1
# Mocha          1
# Bronze         1
# Olive          1
# Name: color, dtype: int64

# %%
sns.barplot(x='price', y='color', data=df, estimator=np.sum)

# %%
sns.jointplot(x='price', y='color', data=df, kind='scatter', height=8, color='m')

# %% [markdown]
# ## how the distance travel affect the prices ?

# %%
sns.jointplot(x='distance', y='price', data=df, kind='scatter', height=8, color='m')

# %% [markdown]
# ### the most expensive cars have the least distance traveled

# %% [markdown]
# ## how the year of use affect the prices ?

# %%
sns.boxplot(x="year", y="price", data=df)

# %%
sns.jointplot(x='year', y='price', data=df, kind='scatter', height=8, color='m')

# %% [markdown]
# ### the latest cars (2010-2022) are the higher in price

# %% [markdown]
# ## what is the relation between distance traveled and year of use?

# %%
sns.jointplot(x='distance', y='year', data=df, kind='scatter', height=8, color='m')

# %%
df.groupby('year').describe()['distance'].sort_values('mean',ascending=False)
# Out:
#       count           mean           std       min       25%       50%  \
# year
# 1993   12.0  204750.000000  57196.829219  130000.0  172500.0  195000.0
# 1991    4.0  200000.000000  40824.829046  150000.0  187500.0  200000.0
# 1996   35.0  198800.000000  61512.695964   45000.0  160000.0  200000.0
# 2000  163.0  197734.490798  72474.012975   15000.0  150000.0  200000.0
# 1999  129.0  194548.519380  65104.220060   15000.0  150000.0  200000.0
# 1994   32.0  193687.500000  71612.504540   55000.0  147500.0  200000.0
# 1998   92.0  192597.826087  61425.387561   40000.0  150000.0  200000.0
# 1992   23.0  192565.217391  73552.594718   85000.0  140000.0  190000.0
# 2002  111.0  188353.153153  62478.330527   15000.0  150000.0  200000.0
# 2001  146.0  187435.616438  60423.771001   25000.0  150000.0  190000.0
# 2004  109.0  187117.513761  58236.028963   59000.0  150000.0  194000.0
# 1997   82.0  185498.378049  60825.387657   50000.0  150000.0  200000.0
# 2006  318.0  175766.710692  59403.920831    8700.0  131250.0  179500.0
# 2008  443.0  175334.604966  64170.737337   10000.0  134000.0  172500.0
# 1995   38.0  174293.815789  63994.796235      45.0  145500.0  173500.0
# 2007  341.0  173541.873900  64599.272004    7716.0  130000.0  170000.0
# 2005  189.0  172961.010582  56470.173421   30000.0  130000.0  180000.0
# 2003   82.0  168841.573171  67070.230370   25000.0  121750.0  167500.0
# 2010  451.0  167816.310421  60603.181138    4000.0  130000.0  165201.0
# 2009  315.0  167259.549206  56900.143909   10000.0  130000.0  166000.0
# 1990    8.0  162750.000000  77083.906047   45000.0  134250.0  160000.0
# 2011  320.0  159689.196875  58933.840790    9000.0  118000.0  150000.0
# 2012  275.0  151075.978182  52994.692349   10000.0  110000.0  150000.0
# 2013  404.0  148410.017327  59686.161061    5000.0  109500.0  150000.0
# 2014  397.0  139744.335013  55718.853238   10700.0  100000.0  135000.0
# 2015  532.0  131686.090226  55575.236276    7000.0   92000.0  130000.0
# 2016  397.0  118891.234257  52891.114721   10000.0   83000.0  112000.0
# 2017  326.0  115714.601227  49843.215265    3650.0   82250.0  110000.0
# 2018  204.0  104140.818627  58068.173974    2000.0   69500.0   90000.0
# 2019  253.0   78438.011858  43747.554197    1000.0   49000.0   73000.0
# 2020  240.0   60220.000000  37983.517897    5200.0   35750.0   50000.0
#
#            75%       max
# year
# 1993  221500.0  300000.0
# 1991  212500.0  250000.0
# 1996  250000.0  312000.0
# 2000  250000.0  360000.0
# 1999  250000.0  350000.0
# 1994  205000.0  375000.0
# 1998  242500.0  300000.0
# 1992  230000.0  370000.0
# 2002  226500.0  350000.0
# 2001  230000.0  325000.0
# 2004  215000.0  360000.0
# 1997  200000.0  350000.0
# 2006  200000.0  370000.0
# 2008  207500.0  361000.0
# 1995  200000.0  320000.0
# 2007  200000.0  370000.0
# 2005  200000.0  301520.0
# 2003  200000.0  320000.0
# 2010  200000.0  371000.0
# 2009  200000.0  365000.0
# 1990  200000.0  300000.0
# 2011  197500.0  350000.0
# 2012  185000.0  330000.0
# 2013  190000.0  350000.0
# 2014  177000.0  350000.0
# 2015  160000.0  350000.0
# 2016  150000.0  340000.0
# 2017  149000.0  280000.0
# 2018  130000.0  375000.0
# 2019   95000.0  248000.0
# 2020   75500.0  230000.0

# %% [markdown]
# ## Transmission types cars prices

# %%
sns.barplot(x='transmission', y='price', data=df, estimator=np.mean)

# %%
df['transmission'].value_counts()
# Out:
# automatic    3482
# manual       2989
# Name: transmission, dtype: int64

# %% [markdown]
# ## How Engine CC affects the price ?

# %%
sns.jointplot(x='CC', y='price', data=df, kind='scatter', height=10, color='m')

# %%
df.groupby('CC').describe()['price'].sort_values('count',ascending=False)
# Out:
#        count           mean           std       min       25%       50%  \
# CC
# 1600  4782.0  148745.608323  67030.110302   35000.0   97000.0  135000.0
# 1500  1387.0  117219.899063  51960.850306   35000.0   80000.0  105000.0
# 1400   293.0  133713.310580  84646.725942   35000.0   55000.0  110000.0
# 1598     2.0  117500.000000  60104.076401   75000.0   96250.0  117500.0
# 1360     1.0  130000.000000           NaN  130000.0  130000.0  130000.0
# 1489     1.0   75000.000000           NaN   75000.0   75000.0   75000.0
# 1490     1.0  155000.000000           NaN  155000.0  155000.0  155000.0
# 1550     1.0  225000.000000           NaN  225000.0  225000.0  225000.0
# 1595     1.0  170000.000000           NaN  170000.0  170000.0  170000.0
# 1599     1.0  155000.000000           NaN  155000.0  155000.0  155000.0
# 1700     1.0   75000.000000           NaN   75000.0   75000.0   75000.0
#
#            75%       max
# CC
# 1600  190000.0  350000.0
# 1500  140000.0  330000.0
# 1400  205000.0  345000.0
# 1598  138750.0  160000.0
# 1360  130000.0  130000.0
# 1489   75000.0   75000.0
# 1490  155000.0  155000.0
# 1550  225000.0  225000.0
# 1595  170000.0  170000.0
# 1599  155000.0  155000.0
# 1700   75000.0   75000.0

# %% [markdown]
# ### most of the cars are in range 1500 to 2000 CC

# %% [markdown]
# ## What is the mean price of Manual and Automatic Tranmission for each manufacturer?

# %%
pd.pivot_table(df, index=['Make'], columns=['transmission'], values=['price'])
# Out:
#                       price
# transmission      automatic         manual
# Make
# Audi                    NaN   75000.000000
# BMW           233114.285714  171687.500000
# Brilliance    112625.000000   95777.777778
# Byd           125642.857143  131022.471910
# Chana                   NaN   47000.000000
# Changan       155000.000000            NaN
# Chery         178138.888889  105650.000000
# Chevrolet     155017.199017  104818.888889
# Chrysler       85000.000000            NaN
# Citroën       160833.333333   73833.333333
# DFM           117000.000000            NaN
# Daewoo         84166.666667   78404.522613
# Daihatsu       42000.000000            NaN
# Ds            285000.000000            NaN
# Emgrand                 NaN  140500.000000
# Faw                     NaN   54000.000000
# Fiat          259366.666667   63737.654321
# Ford          178733.333333   55333.333333
# Geely         113583.333333   99423.280423
# Great Wall              NaN   90000.000000
# Haima         175000.000000   90500.000000
# Honda         141268.292683   67500.000000
# Hyundai       187914.062500  102526.367188
# Jac                     NaN   86500.000000
# Kia           199032.876712   85472.222222
# Lada          127000.000000   81730.434783
# Lifan                   NaN   50000.000000
# MG            245430.555556            NaN
# Mazda         181651.162791   73750.000000
# Mercedes      284904.761905  325000.000000
# Mitsubishi    191012.698413  101436.170213
# Nissan        170220.194647  120033.333333
# Opel          195636.871508   90478.260870
# Peugeot       196149.238806   78066.666667
# Pontiac       280000.000000            NaN
# Proton        119500.000000   81960.000000
# Renault       154506.072874  100917.840376
# Saipa                   NaN   75777.777778
# Seat          236218.750000   69571.428571
# Senova        127571.428571  111750.000000
# Skoda         185115.131579  125562.500000
# Soueast       112500.000000  110000.000000
# Speranza       81047.619048   76155.080214
# Subaru        157000.000000  131500.000000
# Suzuki        166000.000000            NaN
# Toyota        225598.802395  122703.703704
# Volkswagen    210698.630137  121500.000000
# Volvo         285000.000000  200000.000000
# Zotye         145000.000000  170000.000000

# %% [markdown]
# ## Finding the best price of a model for each year

# %%
df2 =pd.pivot_table(df, index=['Make'], columns=['year'], values=['price'],aggfunc='min')
df2
# Out:
#               price                                                   \
# year           1990      1991      1992      1993     1994      1995
# Make
# Audi            NaN       NaN       NaN       NaN  40000.0       NaN
# BMW         80000.0  130000.0  110000.0  130000.0  95000.0       NaN
# Brilliance      NaN       NaN       NaN       NaN      NaN       NaN
# Byd             NaN       NaN       NaN       NaN      NaN       NaN
# Chana           NaN       NaN       NaN       NaN      NaN       NaN
# Changan         NaN       NaN       NaN       NaN      NaN       NaN
# Chery           NaN       NaN       NaN       NaN      NaN       NaN
# Chevrolet       NaN       NaN       NaN       NaN      NaN       NaN
# Chrysler        NaN       NaN       NaN       NaN      NaN       NaN
# Citroën         NaN       NaN       NaN       NaN      NaN       NaN
# DFM             NaN       NaN       NaN       NaN      NaN       NaN
# Daewoo      85000.0       NaN   55000.0       NaN  49000.0   40000.0
# Daihatsu        NaN   42000.0       NaN       NaN      NaN       NaN
# Ds              NaN       NaN       NaN       NaN      NaN       NaN
# Emgrand         NaN       NaN       NaN       NaN      NaN       NaN
# Faw             NaN       NaN       NaN       NaN      NaN       NaN
# Fiat        37000.0       NaN   38000.0   40000.0  35000.0   35000.0
# Ford            NaN       NaN       NaN       NaN      NaN       NaN
# Geely           NaN       NaN       NaN       NaN      NaN       NaN
# Great Wall      NaN       NaN       NaN       NaN      NaN       NaN
# Haima           NaN       NaN       NaN       NaN      NaN       NaN
# Honda           NaN   60000.0   65000.0   70000.0      NaN   65000.0
# Hyundai         NaN       NaN   45000.0       NaN  38000.0   35000.0
# Jac             NaN       NaN       NaN       NaN      NaN       NaN
# Kia             NaN       NaN       NaN   45000.0      NaN   42000.0
# Lada            NaN       NaN       NaN       NaN  35000.0   35000.0
# Lifan           NaN       NaN       NaN       NaN      NaN       NaN
# MG              NaN       NaN       NaN       NaN      NaN       NaN
# Mazda           NaN       NaN       NaN       NaN      NaN       NaN
# Mercedes        NaN       NaN       NaN       NaN      NaN  180000.0
# Mitsubishi  35000.0       NaN   56000.0   55000.0      NaN       NaN
# Nissan          NaN   60000.0       NaN       NaN      NaN       NaN
# Opel            NaN       NaN   52000.0       NaN  55000.0   50000.0
# Peugeot         NaN       NaN   55000.0       NaN  35000.0   45000.0
# Pontiac         NaN       NaN       NaN       NaN      NaN       NaN
# Proton          NaN       NaN       NaN       NaN      NaN       NaN
# Renault     38000.0       NaN       NaN       NaN      NaN   40000.0
# Saipa           NaN       NaN       NaN       NaN      NaN       NaN
# Seat            NaN       NaN   35000.0       NaN  52000.0       NaN
# Senova          NaN       NaN       NaN       NaN      NaN       NaN
# Skoda           NaN       NaN       NaN       NaN      NaN       NaN
# Soueast         NaN       NaN       NaN       NaN      NaN       NaN
# Speranza        NaN       NaN       NaN       NaN      NaN       NaN
# Subaru          NaN       NaN       NaN       NaN      NaN       NaN
# Suzuki          NaN       NaN       NaN       NaN      NaN       NaN
# Toyota      55000.0       NaN   52000.0   75000.0  55000.0   72000.0
# Volkswagen      NaN       NaN       NaN       NaN      NaN       NaN
# Volvo           NaN       NaN       NaN       NaN      NaN       NaN
# Zotye           NaN       NaN       NaN       NaN      NaN       NaN
#
#                                                     ...                      \
# year            1996      1997      1998      1999  ...      2011      2012
# Make                                                ...
# Audi        110000.0       NaN       NaN       NaN  ...       NaN       NaN
# BMW          87000.0  210000.0  140000.0  130000.0  ...       NaN  245000.0
# Brilliance       NaN       NaN       NaN       NaN  ...   85000.0  100000.0
# Byd              NaN       NaN       NaN       NaN  ...   57000.0   85000.0
# Chana            NaN       NaN       NaN       NaN  ...       NaN       NaN
# Changan          NaN       NaN       NaN       NaN  ...       NaN       NaN
# Chery            NaN       NaN       NaN       NaN  ...       NaN       NaN
# Chevrolet    67000.0       NaN       NaN       NaN  ...   57000.0   72000.0
# Chrysler         NaN       NaN   45000.0  125000.0  ...       NaN       NaN
# Citroën          NaN       NaN       NaN       NaN  ...  150000.0  210000.0
# DFM              NaN       NaN       NaN       NaN  ...       NaN       NaN
# Daewoo       45000.0   55000.0   60000.0   55000.0  ...   92000.0   90000.0
# Daihatsu         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Ds               NaN       NaN       NaN       NaN  ...       NaN       NaN
# Emgrand          NaN       NaN       NaN       NaN  ...       NaN       NaN
# Faw              NaN       NaN       NaN       NaN  ...       NaN       NaN
# Fiat         35000.0   40000.0   42000.0   38000.0  ...       NaN       NaN
# Ford             NaN       NaN   35000.0   37000.0  ...       NaN       NaN
# Geely            NaN       NaN       NaN       NaN  ...       NaN       NaN
# Great Wall       NaN       NaN       NaN       NaN  ...       NaN       NaN
# Haima            NaN       NaN       NaN       NaN  ...       NaN       NaN
# Honda            NaN   60000.0       NaN       NaN  ...       NaN  227000.0
# Hyundai      35000.0   35000.0   35000.0   43000.0  ...   83000.0   60000.0
# Jac              NaN       NaN       NaN       NaN  ...  100000.0       NaN
# Kia              NaN   45000.0   58000.0   40000.0  ...  150000.0  145000.0
# Lada             NaN       NaN       NaN       NaN  ...   53000.0   45000.0
# Lifan            NaN       NaN       NaN       NaN  ...       NaN       NaN
# MG               NaN       NaN       NaN       NaN  ...       NaN  139000.0
# Mazda            NaN   45000.0   55000.0       NaN  ...  193000.0       NaN
# Mercedes         NaN       NaN       NaN  138000.0  ...  350000.0       NaN
# Mitsubishi   78000.0   65000.0   65000.0   68000.0  ...  200000.0  170000.0
# Nissan       60000.0       NaN       NaN   68000.0  ...   93000.0  122000.0
# Opel         55000.0   65000.0   55000.0   80000.0  ...       NaN  175000.0
# Peugeot      50000.0   45000.0   55000.0   42000.0  ...  320000.0  130000.0
# Pontiac          NaN       NaN       NaN       NaN  ...       NaN       NaN
# Proton           NaN       NaN       NaN       NaN  ...       NaN  100000.0
# Renault      45000.0   38000.0       NaN   55000.0  ...   80000.0   85000.0
# Saipa            NaN       NaN       NaN       NaN  ...       NaN       NaN
# Seat         37000.0       NaN   50000.0   65000.0  ...  145000.0  150000.0
# Senova           NaN       NaN       NaN       NaN  ...       NaN       NaN
# Skoda            NaN       NaN   65000.0   92000.0  ...  170000.0  160000.0
# Soueast          NaN       NaN       NaN       NaN  ...       NaN       NaN
# Speranza         NaN       NaN       NaN       NaN  ...   60000.0   75000.0
# Subaru           NaN       NaN       NaN       NaN  ...       NaN  195000.0
# Suzuki           NaN       NaN       NaN       NaN  ...       NaN       NaN
# Toyota       85000.0   87000.0   65000.0   65000.0  ...  176000.0  230000.0
# Volkswagen       NaN  143000.0  120000.0   85000.0  ...  188000.0  249000.0
# Volvo            NaN       NaN       NaN       NaN  ...       NaN  200000.0
# Zotye            NaN       NaN       NaN       NaN  ...       NaN       NaN
#
#                                                                         \
# year            2013      2014      2015      2016      2017      2018
# Make
# Audi             NaN       NaN       NaN       NaN       NaN       NaN
# BMW         302000.0  325000.0  305000.0   95000.0       NaN       NaN
# Brilliance  100000.0       NaN       NaN       NaN       NaN       NaN
# Byd          60000.0   92000.0   90000.0   95000.0  110000.0   95000.0
# Chana            NaN       NaN       NaN       NaN       NaN       NaN
# Changan          NaN       NaN       NaN  140000.0       NaN       NaN
# Chery        97000.0       NaN   95000.0       NaN   87000.0  110000.0
# Chevrolet    83000.0   95000.0   95000.0  104000.0  110000.0  120000.0
# Chrysler         NaN       NaN       NaN       NaN       NaN       NaN
# Citroën          NaN  140000.0  170000.0  165000.0       NaN       NaN
# DFM              NaN       NaN  117000.0       NaN       NaN       NaN
# Daewoo      120000.0   78000.0       NaN  115000.0       NaN       NaN
# Daihatsu         NaN       NaN       NaN       NaN       NaN       NaN
# Ds          300000.0  270000.0       NaN       NaN       NaN       NaN
# Emgrand          NaN   86000.0       NaN       NaN       NaN       NaN
# Faw          68000.0       NaN       NaN       NaN       NaN       NaN
# Fiat        125000.0       NaN       NaN  120000.0  155000.0  235000.0
# Ford        160000.0  160000.0  288000.0  250000.0       NaN  265000.0
# Geely        65000.0   77000.0   35000.0   80000.0   85000.0  120000.0
# Great Wall   80000.0  100000.0       NaN       NaN       NaN       NaN
# Haima            NaN       NaN       NaN       NaN       NaN  120000.0
# Honda       212000.0       NaN       NaN  225000.0       NaN       NaN
# Hyundai      70000.0  100000.0  100000.0  100000.0  120000.0  145000.0
# Jac          73000.0       NaN       NaN       NaN       NaN       NaN
# Kia         150000.0  145000.0  145000.0  192000.0  220000.0  210000.0
# Lada         47000.0   40000.0  105000.0   70000.0   90000.0  105000.0
# Lifan            NaN       NaN       NaN       NaN       NaN       NaN
# MG          110000.0  145000.0  155000.0       NaN       NaN  250000.0
# Mazda            NaN       NaN  225000.0  240000.0  270000.0  310000.0
# Mercedes         NaN       NaN       NaN       NaN       NaN       NaN
# Mitsubishi  159000.0  100000.0  157000.0  145000.0  210000.0   85000.0
# Nissan      115000.0   93000.0  120000.0  120000.0  137000.0  155000.0
# Opel        160000.0  175000.0  170000.0  198000.0  145000.0  235000.0
# Peugeot     229999.0  120000.0  135000.0  120000.0  190000.0  150000.0
# Pontiac          NaN       NaN       NaN       NaN       NaN       NaN
# Proton      120000.0  125000.0  150000.0  165000.0       NaN       NaN
# Renault      65000.0  105000.0   65000.0   65000.0   89000.0  135000.0
# Saipa            NaN   60000.0       NaN       NaN       NaN       NaN
# Seat             NaN       NaN  185000.0  225000.0  290000.0  280000.0
# Senova           NaN       NaN  115000.0   70000.0       NaN  170000.0
# Skoda       155000.0  230000.0  185000.0  310000.0       NaN       NaN
# Soueast          NaN       NaN  110000.0       NaN       NaN       NaN
# Speranza     80000.0  100000.0       NaN       NaN   95000.0  112000.0
# Subaru           NaN  195000.0  210000.0       NaN       NaN       NaN
# Suzuki           NaN       NaN  160000.0       NaN       NaN       NaN
# Toyota      167000.0  247000.0  185000.0  275000.0  325000.0  260000.0
# Volkswagen  282000.0  235000.0  295000.0  345000.0       NaN       NaN
# Volvo       250000.0  275000.0  320000.0  300000.0       NaN       NaN
# Zotye            NaN       NaN       NaN       NaN       NaN       NaN
#
#
# year            2019      2020
# Make
# Audi             NaN       NaN
# BMW              NaN       NaN
# Brilliance       NaN       NaN
# Byd          90000.0   85000.0
# Chana            NaN       NaN
# Changan          NaN       NaN
# Chery       135000.0   98500.0
# Chevrolet   100000.0  130000.0
# Chrysler         NaN       NaN
# Citroën     260000.0   85000.0
# DFM              NaN       NaN
# Daewoo           NaN       NaN
# Daihatsu         NaN       NaN
# Ds               NaN       NaN
# Emgrand     195000.0       NaN
# Faw              NaN       NaN
# Fiat         65000.0  120000.0
# Ford             NaN       NaN
# Geely       100000.0       NaN
# Great Wall       NaN       NaN
# Haima            NaN       NaN
# Honda            NaN       NaN
# Hyundai     180000.0  225000.0
# Jac              NaN       NaN
# Kia         270000.0  200000.0
# Lada         50000.0  110000.0
# Lifan            NaN       NaN
# MG           90000.0  130000.0
# Mazda            NaN       NaN
# Mercedes    220000.0       NaN
# Mitsubishi       NaN       NaN
# Nissan      120000.0   80000.0
# Opel        235000.0  235000.0
# Peugeot     185000.0  225000.0
# Pontiac     280000.0       NaN
# Proton      230000.0       NaN
# Renault     128000.0  180000.0
# Saipa            NaN       NaN
# Seat        275000.0  315000.0
# Senova           NaN       NaN
# Skoda            NaN  185000.0
# Soueast          NaN       NaN
# Speranza         NaN       NaN
# Subaru           NaN       NaN
# Suzuki           NaN       NaN
# Toyota      160000.0  300000.0
# Volkswagen       NaN       NaN
# Volvo            NaN       NaN
# Zotye       145000.0  170000.0
#
# [49 rows x 31 columns]

# %% [markdown]
# ## One Hot Encoder
#
# ### Encode categorical features as a one-hot numeric array.
# ### This encoding is needed for feeding categorical data to many scikit-learn estimators and models

# %%
df['CC'].value_counts()
# Out:
# 1600    4782
# 1500    1387
# 1400     293
# 1598       2
# 1550       1
# 1489       1
# 1490       1
# 1599       1
# 1595       1
# 1700       1
# 1360       1
# Name: CC, dtype: int64

# %%
i1=df[ (df['CC'] == 1360) ].index
i2=df[ (df['CC'] == 1700) ].index
i3=df[ (df['CC'] == 1595) ].index
i4=df[ (df['CC'] == 1599) ].index
i5=df[ (df['CC'] == 1490) ].index
i6=df[ (df['CC'] == 1489) ].index
i7=df[ (df['CC'] == 1550) ].index
i8=df[ (df['CC'] == 1598) ].index

# %%
idx = [i1,
i2,
i3,
i4,
i5,
i6,
i7,
i8]

# %%
for i in idx :
    df.drop(i , axis=0, inplace=True)

# %%
df['CC'] = df['CC'].apply(str)

# %%
df.describe()
# Out:
#               year       distance          price
# count  6462.000000    6462.000000    6462.000000
# mean   2010.277004  150539.402043  141297.353606
# std       6.242905   66930.240560   66301.367534
# min    1990.000000      45.000000   35000.000000
# 25%    2007.000000  100000.000000   90000.000000
# 50%    2011.000000  150000.000000  128000.000000
# 75%    2015.000000  200000.000000  180000.000000
# max    2020.000000  375000.000000  350000.000000

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10)

# %%
encoder = OneHotEncoder(handle_unknown='ignore')

# %%
encoder.fit(x_train) 
x_test = encoder.transform(x_test)
x_train = encoder.transform(x_train)

# %% [markdown]
# ## Scaling data

# %%
scaler = StandardScaler(with_mean=False)

scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## Different ML models

# %%
models = {
    'LR': LinearRegression(),
    'DT': DecisionTreeRegressor(),
    'KNN': KNeighborsRegressor(),
    'SVM': SVR(), 
    'RF': RandomForestRegressor(),
    'XGB': XGBRegressor()
         }


for name, model in models.items():
    print(f'Training {name}...')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Testing RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print(f'Testing MAE: {mean_absolute_error(y_test, y_pred)}')
    print(f'Testing R2: {r2_score(y_test, y_pred)}')
    print('-'*50)
# Out:
# Training LR...
# Testing RMSE: 25393.44243605435
# Testing MAE: 18277.04154845295
# Testing R2: 0.852171430695389
# --------------------------------------------------
# Training DT...
# Testing RMSE: 29845.03484839663
# Testing MAE: 19614.375579598145
# Testing R2: 0.7957982802360422
# --------------------------------------------------
# Training KNN...
# Testing RMSE: 46716.34770083605
# Testing MAE: 30862.131375579596
# Testing R2: 0.49967410723758976
# --------------------------------------------------
# Training SVM...
# Testing RMSE: 66562.86869531928
# Testing MAE: 51356.597393276206
# Testing R2: -0.01573233036980448
# --------------------------------------------------
# Training RF...
# Testing RMSE: 25107.881869901656
# Testing MAE: 16508.802358983965
# Testing R2: 0.8554775324483482
# --------------------------------------------------
# Training XGB...
# Testing RMSE: 23382.640983596
# Testing MAE: 16066.183563562596
# Testing R2: 0.8746563498153697
# --------------------------------------------------

# %% [markdown]
# ## Cross Validation and Hyperparameter tuning for XGBRegressor
#
# ### XGBoost is a popular and efficient open-source implementation of the gradient boosted trees algorithm. Gradient boosting is a supervised learning algorithm, which attempts to accurately predict a target variable by combining the estimates of a set of simpler, weaker models.

# %%
model_f = XGBRegressor()
params = [
    {'criterion': ['gini', 'entropy'],
     'max_depth': range(3, 20),
     'n_estimators': range(200, 501, 50)
     
    }
]

# %% [markdown]
# #### max_depth: The maximum depth of a tree,  is used to control over-fitting as higher depth will allow model to learn relations very specific to a particular sample. Increasing this value will make the model more complex and more likely to overfit.
#
# #### n_estimators: The number of trees (or rounds) in an XGBoost model
#
# #### criterion : This parameter is the function used to measure the quality of nodes split of the features and it allows users to choose between ‘gini‘ or ‘entropy‘

# %%
gs_f = GridSearchCV(estimator=model_f, param_grid=params, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=3)

# %%
gs_f.fit(x_train , y_train)
# Out:
# Fitting 5 folds for each of 238 candidates, totalling 1190 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 1190 out of 1190 | elapsed: 21.5min finished
# [18:58:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "criterion" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              n_jobs=-1,
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(3, 20),
#                           'n_estimators': range(200, 501, 50)}],
#              scoring='neg_mean_absolute_error', verbose=3)

# %%
gs_f.best_score_
# Out:
# -15823.686586320264

# %%
gs_f.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'n_estimators': 500}

# %%
model_en = gs_f.best_estimator_
model_en
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              criterion='gini', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=3, max_leaves=0,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=0, reg_alpha=0, ...)

# %%
model_en.fit(x_train, y_train)
# Out:
# [19:00:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "criterion" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              criterion='gini', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_to_onehot=4, max_delta_step=0, max_depth=3, max_leaves=0,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, predictor='auto',
#              random_state=0, reg_alpha=0, ...)

# %%
y_pred = model_en.predict(x_test)
print(np.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_absolute_error(y_test, y_pred))
print(f'Testing R2: {r2_score(y_test, y_pred)}')
# Out:
# 21096.89653345914
# 14819.024119251178
# Testing R2: 0.8930067667812909

# %% [markdown]
# ## saving model

# %%
import joblib

# %%
joblib.dump(model_en, 'model_en.h5')
# Out:
# ['model_en.h5']

# %%
joblib.dump(encoder, 'encoder.h5')
# Out:
# ['encoder.h5']

# %%
joblib.dump(scaler, 'en_scaler.h5')
# Out:
# ['en_scaler.h5']

# %%
client = ["Hyundai", "Verna", 2014 , 1600 ,143000 ,"manual", "Silver"]
client = encoder.transform([client])
client = scaler.transform(client)
prediction = model.predict(client)[0]
prediction
# Out:
# 120279.22
